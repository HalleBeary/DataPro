# %% [markdown]
# Design Questions:
#
# How do the agents look? What should they be capable of?
# - Data Analysis agent: Translate NL to query and extract relevant data + perhaps other data that could be relevant.
# - Visualization agent: What makes it really agentic AI: different visualization categories, highlight importance, suggestions for other graphs/data

# %% [markdown]
# Streamlit for UI? Build CLI first, add later
#
#
# User interface:
#  - Does user know which database corresponds to which data? Agentic AI to assign query to correct database?
#  - Possible to ask multiple questions at once? How is this designed?
#  - Follow up questions?

# %% [markdown]
# Error handling:
#
# - Are authentication/ratelimit etc errors handled correctly?
